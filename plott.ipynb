# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("Dataset_to_plot.csv")

def _3d_data_plot(data, labels=None):
    """Wrapper for 3D data plot
    
    Parameters:
        data: pandas dataframe
        labels: labels of the data points(if available)
        
    """
    fig = plt.figure(figsize=(15,10))
    ax = fig.add_subplot( projection='3d')

    g = ax.scatter(data["P_Genre"], data["S_Genre"], data["T_Genre"],c=data['Cluster_Id'])
    # ax.set_xlabel("Credit amount")
    # ax.set_ylabel("Duration")
    # ax.set_zlabel("Age")
    plt.tight_layout()

# %%
_3d_data_plot(df)

# %%
df.describe()
# Out:
#        Unnamed: 0       index    P_Genre     S_Genre     T_Genre  Cluster_Id
# count  400.000000  400.000000  400.00000  400.000000  400.000000  400.000000
# mean   199.500000  262.947500    3.05000    6.520000    8.380000   20.080000
# std    115.614301  189.612174    1.46385    3.868075    4.714995   19.087678
# min      0.000000    0.000000    0.00000    0.000000    0.000000    0.000000
# 25%     99.750000   99.750000    2.00000    3.000000    4.000000    8.000000
# 50%    199.500000  200.500000    4.00000    7.000000   10.000000   13.000000
# 75%    299.250000  433.250000    4.00000   10.000000   12.000000   28.000000
# max    399.000000  616.000000    4.00000   13.000000   15.000000   81.000000
